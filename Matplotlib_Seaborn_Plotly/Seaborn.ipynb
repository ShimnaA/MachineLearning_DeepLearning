# %%
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Get a relationship between Age and Fare
titanic.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic.fare
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
sns.jointplot(x='age', y='fare', data=titanic)

# %%
titanic[titanic['fare'] > 400]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male deck embark_town alive  alone
# 258  woman       False  NaN   Cherbourg   yes   True
# 679    man        True    B   Cherbourg   yes  False
# 737    man        True    B   Cherbourg   yes   True

# %%
sns.distplot(titanic['fare'], kde=True, color='red', bins =10)

# %%
sns.boxplot(x='class', y='age',data=titanic)

# %%
sns.swarmplot(x='class', y='age',data=titanic)
# Out:
# f:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1311: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# f:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1315: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.countplot(x='sex', data=titanic)

# %%
titanic[titanic['sex']=='male'].__len__()
# Out:
# 577

# %%
sns.heatmap(titanic.corr())
import matplotlib.pyplot as plt
plt.title("Correlation")
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
g = sns.FacetGrid(titanic, col='sex' )
g.map(plt.hist, 'age')

# %%
titanic['age'].mean()
# Out:
# 29.69911764705882

# %%
titanic[titanic['sex']=='male']['age'].mean()
# Out:
# 30.72664459161148

# %%
titanic[titanic['sex']=='female']['age'].mean()
# Out:
# 27.915708812260537
